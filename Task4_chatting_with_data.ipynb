# %%
import os 
os.environ["GOOGLE_API_KEY"] = "AQ.Ab8RN6LbkHmJjj2EvSzS0C95BKohk2yw5gO_URa1vKuWdgZb-g"

# %%
from langchain_community.utilities import SQLDatabase
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_community.agent_toolkits import create_sql_agent

# %%
db = SQLDatabase.from_uri("sqlite:///olist.db")
llm = ChatGoogleGenerativeAI(model="gemini-1.5-flash", temperature=0)
agent = create_sql_agent(
    llm=llm,
    db=db,
    agent_type="openai-tools",
    verbose=True
)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 3
#       1 db = SQLDatabase.from_uri("sqlite:///olist.db")
#       2 llm = ChatGoogleGenerativeAI(model="gemini-1.5-flash", temperature=0)
# ----> 3 agent = create_sql_agent(
#       4     llm=llm,
#       5     db=db,
#       6     agent_type="openai-tools",
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\langchain_community\agent_toolkits\sql\base.py:119, in create_sql_agent(llm, toolkit, agent_type, callback_manager, prefix, suffix, format_instructions, input_variables, top_k, max_iterations, max_execution_time, early_stopping_method, verbose, agent_executor_kwargs, extra_tools, db, prompt, **kwargs)
#      46 def create_sql_agent(
#      47     llm: BaseLanguageModel,
#      48     toolkit: Optional[SQLDatabaseToolkit] = None,
#    (...)     67     **kwargs: Any,
#      68 ) -> AgentExecutor:
#      69     """Construct a SQL agent from an LLM and toolkit or database.
#      70
#      71     Args:
#    (...)    117
#     118     """  # noqa: E501
# --> 119     from langchain.agents import (
#     120         create_openai_functions_agent,
#     121         create_openai_tools_agent,
#     122         create_react_agent,
#     123         create_tool_calling_agent,
#     124     )
#     125     from langchain.agents.agent import (
#     126         AgentExecutor,
#     127         RunnableAgent,
#     128         RunnableMultiActionAgent,
#     129     )
#     130     from langchain.agents.agent_types import AgentType
#
# ImportError: cannot import name 'create_openai_functions_agent' from 'langchain.agents' (c:\Users\MSI\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\langchain\agents\__init__.py)
